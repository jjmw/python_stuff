# %%
import json
import urllib.request

# %%
data = urllib.request.urlopen('http://www.nos.nl')

# %%
data.read()
# Out:
# b'\n<!DOCTYPE html><!--[if lt IE 7]><html class="no-js lt-ie10 lt-ie9 lt-ie8 lt-ie7" lang="nl"><![endif]--><!--[if IE 7]><html class="no-js lt-ie10 lt-ie9 lt-ie8" lang="nl"><![endif]--><!--[if IE 8]><html class="no-js lt-ie10 lt-ie9" lang="nl"><![endif]--><!--[if (gt IE 8) & (!IEMobile)]><html class="no-js lt-ie10 ie9-desktop" lang="nl"><![endif]--><!--[if (gt IE 8) & (IEMobile)]><html class="no-js lt-ie10 ie9-mobile" lang="nl"><![endif]--><!--[if !IE]><!--><html class="no-js" lang="nl"><!--<![endif]--><head><meta charset="utf-8" /><meta name="viewport" content="width=device-width, initial-scale=1.0" /><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><title>\n        NOS.nl - Nieuws, Sport en Evenementen | Nederlandse Omroep Stichting\n    </title><link rel="shortcut icon" href="/favicon.ico" type="image/x-icon"><link rel="apple-touch-icon" href="/apple-touch-icon.png"><meta name="app-name" content="NOS"><meta name="apple-itunes-app" content="app-id=516491461"><meta name="google-play-app" content="app-id=nl.nos.app"><meta property="og:type" content="website" /><meta property="og:title" content="Nederlandse Omroep Stichting" /><meta property="og:description" content="NOS.nl - Nieuws, Sport en Evenementen op Radio, TV en Internet" /><meta property="og:image" content="http://nos.nl/img/social/nos.jpg?161123" /><meta property="og:image:width" content="1200" /><meta property="og:image:height" content="630" /><meta property="og:url" content="http://nos.nl/" /><meta property="twitter:card" content="app" /><meta property="twitter:site" content="@NOS" /><meta property="twitter:app:id:iphone" content="id516491461" /><meta property="twitter:app:url:iphone" content="nl.nos.app://open" /><meta property="twitter:app:id:ipad" content="id516491461" /><meta property="twitter:app:url:ipad" content="nl.nos.app://open" /><meta property="twitter:app:id:googleplay" content="nl.nos.app" /><meta property="twitter:app:country" content="nl" /><link href="/bundles/nossite/css/styles.css?161123" media="all" type="text/css" rel="stylesheet" /><script type="text/javascript" src="/js/lib/modernizr/modernizr.min.js?161123"></script><!--[if lt IE 9]><script type="text/javascript" src="/js/lib/vendor/respond/respond.1.1.0.min.js?161123"></script><![endif]--></head><body class="homepage" data-comscore="{&quot;name&quot;:&quot;track.click.homepage&quot;}"><header id="nav" class="nav-wrapper"><div class=\'cf\'><div class="a11y"><ul class="a11y__list"><li><a class="a11y__link" href="#menu">Ga naar het hoofdmenu</a></li><li><a class="a11y__link" href="#content">Ga naar de inhoud</a></li></ul></div><nav class="nav js-nav" data-comscore="{&quot;nos_origin&quot;:&quot;menu&quot;}"><div class="nav__row"><div class="nav__left clearfix"><a href="#menu" class="nav__menuicon img-menu-hover js-menu-trigger js-event-click" data-js-menu-target="nav__main" data-comscore="{&quot;nos_menu&quot;:&quot;menu_toggle&quot;}"><span class="ir img-menu"></span></a><a id="logo" href="/" class="js-event-click" data-comscore="{&quot;nos_menu&quot;:&quot;logo&quot;}"><span class="ir img-nos"></span><span class="visuallyhidden">NOS</span></a></div><div class="nav__main js-nav-collapse"><ul id="menu" class="nav__list clearfix"><li id="nav-nieuws" class="nav__item nav__item--hover js-menu-item"><a href="/nieuws/" class="nav__category js-event-click  js-news js-dashboard-trigger" data-js-dashboard-target="nieuws" data-comscore="{&quot;nos_menu&quot;:&quot;nieuws&quot;}">\n  Nieuws\n</a><a href="#menu-nieuws" title="" class="nav__expand no-js-hidden js-submenu-toggle js-event-click" data-comscore="{&quot;nos_menu_nieuws&quot;:&quot;mobile_toggle&quot;}"><span class="icon-plus right js-menu-icon nav__expand__icon"></span></a><div id="menu-nieuws" class="subnav nav__item__hover"><div class="subnav__row"><nav class="subnav__categories"><ul class="subnav__list"><li class="subnav__head"><a href="/nieuws/" class="subnav__link js-event-click" data-comscore="{&quot;nos_menu_news&quot;:&quot ...

# %%
t = {"name":"Luke Skywalker","height":"172","mass":"77","hair_color":"blond","skin_color":"fair","eye_color":"blue","birth_year":"19BBY","gender":"male","homeworld":"http://swapi.co/api/planets/1/","films":["http://swapi.co/api/films/6/","http://swapi.co/api/films/3/","http://swapi.co/api/films/2/","http://swapi.co/api/films/1/","http://swapi.co/api/films/7/"],"species":["http://swapi.co/api/species/1/"],"vehicles":["http://swapi.co/api/vehicles/14/","http://swapi.co/api/vehicles/30/"],"starships":["http://swapi.co/api/starships/12/","http://swapi.co/api/starships/22/"],"created":"2014-12-09T13:50:51.644000Z","edited":"2014-12-20T21:17:56.891000Z","url":"http://swapi.co/api/people/1/"}
td = json.dumps(t)

# %%
films = [y for x, y in t.items() if x == 'films'][0]
films
# Out:
# ['http://swapi.co/api/films/6/',
#  'http://swapi.co/api/films/3/',
#  'http://swapi.co/api/films/2/',
#  'http://swapi.co/api/films/1/',
#  'http://swapi.co/api/films/7/']

# %%
for x in films:
    print(x)
# Out:
# http://swapi.co/api/films/6/
# http://swapi.co/api/films/3/
# http://swapi.co/api/films/2/
# http://swapi.co/api/films/1/
# http://swapi.co/api/films/7/
